# %% [markdown]
# # Notebook 02 — Results on Real PJM Data (or Synthetic Fallback)
#
# Run the full benchmark and regenerate all five report figures.
# If `data/pjm/rt_lmps.csv` is present this notebook uses real PJM Data Miner 2 exports;
# otherwise it labels every figure as synthetic.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from src.eval import plots as pmod
pmod.main()  # writes the five figures to ../figures/

# %%
from IPython.display import Image, display
for name in [
    'fig1_dispatch_overview',
    'fig2_revenue_comparison',
    'fig3_gap_vs_horizon',
    'fig4_revenue_decomposition',
    'fig5_rmse_vs_gap',
]:
    display(Image(filename=f'../figures/{name}.png'))
